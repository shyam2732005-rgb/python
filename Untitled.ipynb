# %%
A = int(input("ENTER THE NUMBER:"))
B = int(input("ENTER  THE NUMBER:"))
SUM = A+B
print("sum=", SUM)
# Out:
# ENTER THE NUMBER: 30
# ENTER  THE NUMBER: 40
# sum= 70

# %%
A = int(input("ENTER THE NUMBER:"))
B = int(input("ENTER  THE NUMBER:"))
sub = A-B
print("sub=", sub)
# Out:
# ENTER THE NUMBER: 30
# ENTER  THE NUMBER: 40
# sub= -10

# %%
A = int(input("ENTER THE NUMBER:"))
B = int(input("ENTER  THE NUMBER:"))
div = A/B
print("div=", div)
# Out:
# ENTER THE NUMBER: 30
# ENTER  THE NUMBER: 40
# div= 0.75

# %%
A = int(input("ENTER THE NUMBER:"))
B = int(input("ENTER  THE NUMBER:"))
mul = A*B
print("mul=",mul)
# Out:
# ENTER THE NUMBER: 30
# ENTER  THE NUMBER: 40
# mul= 1200
